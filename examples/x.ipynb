# %%
using Pkg
Pkg.activate(joinpath(@__DIR__, ".."))
# Out:
#   Activating project at `~/Workspace/juliwave/JuliWave.jl`

# %%
using NPZ
vp_npy = npzread(joinpath(@__DIR__, "vp.npy"))
# Out:
# 301×301 Matrix{Float32}:
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5  …  3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5  …  3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
#  ⋮                        ⋮              ⋱       ⋮                        ⋮
#  1.5  1.5  1.5  1.5  1.5  1.5  1.5  1.5     3.5  3.5  3.5  3.5  3.5  3.5  3.5
# ...

# %%
using PyPlot

# %%
imshow(vp_npy)
gcf()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
